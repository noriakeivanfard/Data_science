# %%
import requests
import json
import pandas as pd

# %%
data = requests.get("http://api.alquran.cloud/v1/juz/22/quran-uthmani")

# %%
data
# Out:
# <Response [200]>

# %%
data.text
# Out:
# '{"code":200,"status":"OK","data":{"number":22,"ayahs":[{"number":3564,"text":"\\u06de \\u0648\\u064e\\u0645\\u064e\\u0646 \\u064a\\u064e\\u0642\\u0652\\u0646\\u064f\\u062a\\u0652 \\u0645\\u0650\\u0646\\u0643\\u064f\\u0646\\u0651\\u064e \\u0644\\u0650\\u0644\\u0651\\u064e\\u0647\\u0650 \\u0648\\u064e\\u0631\\u064e\\u0633\\u064f\\u0648\\u0644\\u0650\\u0647\\u0650\\u06e6 \\u0648\\u064e\\u062a\\u064e\\u0639\\u0652\\u0645\\u064e\\u0644\\u0652 \\u0635\\u064e\\u0670\\u0644\\u0650\\u062d\\u064b\\u06ed\\u0627 \\u0646\\u0651\\u064f\\u0624\\u0652\\u062a\\u0650\\u0647\\u064e\\u0627\\u0653 \\u0623\\u064e\\u062c\\u0652\\u0631\\u064e\\u0647\\u064e\\u0627 \\u0645\\u064e\\u0631\\u0651\\u064e\\u062a\\u064e\\u064a\\u0652\\u0646\\u0650 \\u0648\\u064e\\u0623\\u064e\\u0639\\u0652\\u062a\\u064e\\u062f\\u0652\\u0646\\u064e\\u0627 \\u0644\\u064e\\u0647\\u064e\\u0627 \\u0631\\u0650\\u0632\\u0652\\u0642\\u064b\\u06ed\\u0627 \\u0643\\u064e\\u0631\\u0650\\u064a\\u0645\\u064b\\u06ed\\u0627","surah":{"number":33,
# ...

# %%
csv_df = pd.read_csv(r'http://api.alquran.cloud/v1/juz/22/quran-uthmani.csv')

# %%
csv_df
# Out:
# Empty DataFrame
# ...

# %%
text = "\u06de \u0648\u064e\u0645\u064e\u0646\u0652\u064a\u064e\u0642\u0652\u0646\u064f\u062a\u0652\u0645\u0650\u0646\u0652\u0643\u064f\u0646\u0651\u064e \u0644\u0650\u0644\u0651\u064e\u0647\u0650 \u0648\u064e\u0631\u064e\u0633\u064f\u0648\u0644\u0650\u0647\u0650 \u0648\u064e\u062a\u064e\u0639\u0652\u0645\u064e\u0644\u0652 \u0635\u064e\u0627\u0644\u0650\u062d\u064b\u0627 \u0646\u064f\u0624\u0652\u062a\u0650\u0647\u064e\u0627 \u0623\u064e\u062c\u0652\u0631\u064e\u0647\u064e\u0627 \u0645\u064e\u0631\u0651\u064e\u062a\u064e\u064a\u0652\u0646\u0650 \u0648\u064e\u0623\u064e\u0639\u0652\u062a\u064e\u062f\u0652\u0646\u064e\u0627 \u0644\u064e\u0647\u064e\u0627 \u0631\u0650\u0632\u0652\u0642\u064b\u0627 \u0643\u064e\u0631\u0650\u064a\u0645\u064b\u0627\u0627\u0644\u0642\u0631\u0622\u0646\u0627\u0644\u0643\u0631\u064a\u0645 \u0627\u0644\u0645\u0628\u0633\u0637\u062a\u0634\u0643\u064a\u0644\u0628\u0633\u064a\u0637"
text
# Out:
# '۞ وَمَنْيَقْنُتْ مِنْكُنَّ لِلَّهِ وَرَسُولِهِ وَتَعْمَلْ صَالِحًا نُؤْتِهَا أَجْرَهَا مَرَّتَيْنِ وَأَعْتَدْنَا لَهَا رِزْقًا كَرِيمًاالقرآنالكريم المبسطتشكيلبسيط'
