# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("laptops_train.csv")
df.head()
# Out:
#              0            1          2            3   \
# 0  Manufacturer   Model Name   Category  Screen Size
# 1         Apple  MacBook Pro  Ultrabook        13.3"
# 2         Apple  Macbook Air  Ultrabook        13.3"
# 3            HP       250 G6   Notebook        15.6"
# 4         Apple  MacBook Pro  Ultrabook        15.4"
#
#                                    4                           5     6   \
# 0                              Screen                         CPU   RAM
# 1  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 2                            1440x900        Intel Core i5 1.8GHz   8GB
# 3                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 4  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
#
#                     7                             8                 9   \
# 0              Storage                           GPU  Operating System
# 1            128GB SSD  Intel Iris Plus Graphics 640             macOS
# 2  128GB Flash Storage        Intel HD Graphics 6000             macOS
# 3            256GB SSD         Intel HD Graphics 620             No OS
# 4            512GB SSD            AMD Radeon Pro 455             macOS
#
#                          10      11           12
# 0  Operating System Version  Weight        Price
# 1                       NaN  1.37kg  11912523.48
# 2                       NaN  1.34kg   7993374.48
# 3                       NaN  1.86kg      5112900
# 4                       NaN  1.83kg   22563005.4

# %%
headers = ['Manufacturer','Model Name','Category','Screen Size','Screen	','CPU','RAM','Storage','GPU',
           'Operating System','Operating System Version','Weight','Price']
df.columns = headers
df.head()
# Out:
#    Manufacturer   Model Name   Category  Screen Size  \
# 0  Manufacturer   Model Name   Category  Screen Size
# 1         Apple  MacBook Pro  Ultrabook        13.3"
# 2         Apple  Macbook Air  Ultrabook        13.3"
# 3            HP       250 G6   Notebook        15.6"
# 4         Apple  MacBook Pro  Ultrabook        15.4"
#
#                              Screen\t                         CPU   RAM  \
# 0                              Screen                         CPU   RAM
# 1  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 2                            1440x900        Intel Core i5 1.8GHz   8GB
# 3                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 4  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
#
#                Storage                           GPU  Operating System  \
# 0              Storage                           GPU  Operating System
# 1            128GB SSD  Intel Iris Plus Graphics 640             macOS
# 2  128GB Flash Storage        Intel HD Graphics 6000             macOS
# 3            256GB SSD         Intel HD Graphics 620             No OS
# 4            512GB SSD            AMD Radeon Pro 455             macOS
#
#    Operating System Version  Weight        Price
# 0  Operating System Version  Weight        Price
# 1                       NaN  1.37kg  11912523.48
# 2                       NaN  1.34kg   7993374.48
# 3                       NaN  1.86kg      5112900
# 4                       NaN  1.83kg   22563005.4

# %%
df = df.replace('?', np.nan)

# %%
df
# Out:
#      Manufacturer       Model Name   Category  Screen Size  \
# 0    Manufacturer       Model Name   Category  Screen Size
# 1           Apple      MacBook Pro  Ultrabook        13.3"
# 2           Apple      Macbook Air  Ultrabook        13.3"
# 3              HP           250 G6   Notebook        15.6"
# 4           Apple      MacBook Pro  Ultrabook        15.4"
# ..            ...              ...        ...          ...
# 973          Dell     Alienware 17     Gaming        17.3"
# 974       Toshiba  Tecra A40-C-1DF   Notebook        14.0"
# 975          Asus        Rog Strix     Gaming        17.3"
# 976            HP      Probook 450   Notebook        15.6"
# 977        Lenovo    ThinkPad T460   Notebook        14.0"
#
#                                Screen\t                          CPU   RAM  \
# 0                                Screen                          CPU   RAM
# 1    IPS Panel Retina Display 2560x1600         Intel Core i5 2.3GHz   8GB
# 2                              1440x900         Intel Core i5 1.8GHz   8GB
# 3                     Full HD 1920x1080   Intel Core i5 7200U 2.5GHz   8GB
# 4    IPS Panel Retina Display 2880x1800         Intel Core i7 2.7GHz  16GB
# ..                                  ...                          ...   ...
# 973                   Full HD 1920x1080  Intel Core i7 6700HQ 2.6GHz  32GB
# 974                   Full HD 1920x1080   Intel Core i5 6200U 2.3GHz   8GB
# 975                   Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz  16GB
# 976         IPS Panel Full HD 1920x1080  Intel Core i5 7200U 2.70GHz   8GB
# 977                            1366x768   Intel Core i5 6200U 2.3GHz   4GB
#
#                   Storage                           GPU  Operating System  \
# 0                 Storage                           GPU  Operating System
# 1               128GB SSD  Intel Iris Plus Graphics 640             macOS
# 2     128GB Flash Storage        Intel HD Graphics 6000             macOS
# 3               256GB SSD         Intel HD Graphics 620             No OS
# 4               512GB SSD            AMD Radeon Pro 455             macOS
# ..                    ...                           ...               ...
# 973  256GB SSD +  1TB HDD       Nvidia GeForce GTX 1070           Windows
# 974             256GB SSD         Intel HD Graphics 520           Windows
# 975  256GB SSD +  1TB HDD       Nvidia GeForce GTX 1060           Windows
# 976  128GB SSD +  1TB HDD          Nvidia GeForce 930MX           Windows
# 977          508GB Hybrid         Intel HD Graphics 520           Windows
#
#      Operating System Version  Weight        Price
# 0    Operating System Version  Weight        Price
# 1                         NaN  1.37kg  11912523.48
# 2                         NaN  1.34kg   7993374.48
# 3                         NaN  1.86kg      5112900
# 4                         NaN  1.83kg   22563005.4
# ..                        ...     ...          ...
# 973                        10  4.42kg     24897600
# 974                        10  1.95kg     10492560
# 975                        10  2.73kg   18227710.8
# 976                        10  2.04kg      8705268
# 977                         7  1.70kg      8909784
#
# [978 rows x 13 columns]

# %%
df.dtypes
# Out:
# Manufacturer                object
# Model Name                  object
# Category                    object
# Screen Size                 object
# Screen\t                    object
# CPU                         object
# RAM                         object
# Storage                     object
# GPU                         object
# Operating System            object
# Operating System Version    object
# Weight                      object
# Price                       object
# dtype: object

# %%
df.replace("?", np.nan, inplace=True)

# %%
df.describe()
# Out:
#        Manufacturer Model Name  Category Screen Size           Screen\t  \
# count           978        978       978         978                978
# unique           20        489         7          19                 39
# top            Dell     XPS 13  Notebook       15.6"  Full HD 1920x1080
# freq            232         22       549         494                397
#
#                                CPU  RAM    Storage                    GPU  \
# count                          978  978        978                    978
# unique                         107    9         37                     99
# top     Intel Core i5 7200U 2.5GHz  8GB  256GB SSD  Intel HD Graphics 620
# freq                           151  483        318                    225
#
#        Operating System Operating System Version Weight    Price
# count               978                      842    978      978
# unique                8                        5    167      640
# top             Windows                       10  2.2kg  9772308
# freq                837                      819     98       12

# %%
df.describe(include="all")
# Out:
#        Manufacturer Model Name  Category Screen Size           Screen\t  \
# count           978        978       978         978                978
# unique           20        489         7          19                 39
# top            Dell     XPS 13  Notebook       15.6"  Full HD 1920x1080
# freq            232         22       549         494                397
#
#                                CPU  RAM    Storage                    GPU  \
# count                          978  978        978                    978
# unique                         107    9         37                     99
# top     Intel Core i5 7200U 2.5GHz  8GB  256GB SSD  Intel HD Graphics 620
# freq                           151  483        318                    225
#
#        Operating System Operating System Version Weight    Price
# count               978                      842    978      978
# unique                8                        5    167      640
# top             Windows                       10  2.2kg  9772308
# freq                837                      819     98       12
